# %%
import pandas as pd

file_to_load = "Resources/nba_2017_salary.csv"

salary = pd.read_csv(file_to_load)
salary.head()
# Out:
#               NAME POSITION                 TEAM      SALARY
# 0     LeBron James       SF  Cleveland Cavaliers  30963450.0
# 1      Mike Conley       PG    Memphis Grizzlies  26540100.0
# 2       Al Horford        C       Boston Celtics  26540100.0
# 3    Dirk Nowitzki       PF     Dallas Mavericks  25000000.0
# 4  Carmelo Anthony       SF      New York Knicks  24559380.0

# %%
team_salary_avg = salary.groupby(["TEAM"]).mean()["SALARY"].rename("Average Salary")
new_df = pd.DataFrame(team_salary_avg)
new_df.style.format({"Average Salary":"${:,.2f}"})
new_df
# Out:
#                         Average Salary
# TEAM
# Atlanta Hawks             4.917651e+06
# Boston Celtics            5.050278e+06
# Brooklyn Nets             4.435575e+06
# Charlotte Hornets         5.318635e+06
# Chicago Bulls             6.620476e+06
# Cleveland Cavaliers       1.056409e+07
# Dallas Mavericks          6.697628e+06
# Denver Nuggets            4.645013e+06
# Detroit Pistons           6.574762e+06
# Golden State Warriors     1.118341e+07
# Houston Rockets           6.395729e+06
# Indiana Pacers            6.147606e+06
# LA Clippers               7.607628e+06
# Los Angeles Lakers        5.806584e+06
# Memphis Grizzlies         4.820863e+06
# Miami Heat                7.200606e+06
# Milwaukee Bucks           6.398655e+06
# Minnesota Timberwolves    4.595232e+06
# New Orleans Pelicans      6.991604e+06
# New York Knicks           6.595230e+06
# Oklahoma City Thunder     6.043539e+06
# Orlando Magic             6.378996e+06
# Philadelphia 76ers        4.437979e+06
# ...

# %%
import requests
import pymongo
from bs4 import BeautifulSoup as bs

# %%
url = "https://www.basketball-reference.com/leagues/NBA_2018_per_minute.html"
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = bs(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/bbr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
#    <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202104191" rel="dns-prefetch"/>
#    <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
#    <script async="true" type="text/javascript">
#     (function() {
# 	var host = window.location.hostname;
# 	var element = document.createElement('script');
# 	var firstScript = document.getElementsByTagName('script')[0];
# 	var url = 'https://quantcast.mgr.consensu.org'
# 	    .concat('/choice/', 'XwNYEpNeFfhfr', '/', host, '/choice.js')
# 	var uspTries = 0;
# 	var uspTriesLimit = 3;
# 	element.async = true;
# 	element.type = 'text/javascript';
# 	element.src = url;
#
# ...

# %%
#per_game = soup.find(name = 'table', attrs = {'id' : 'per_minute_stats'})

# %%
#print(per_game)

# %%
#season_stats = []

# %%
#for row in per_game.find_all('tr')[1:]:
 #   player = {}
  #  player["Name"] = row.find('a').text.strip()
   # player["Team"] = row.find('td', {'data-stat' : 'team_id'}).text
   # player['Age'] = row.find('td', {'data-stat' : 'age'}).text
   # season_stats.append(player)

# %%
#pd.DataFrame(season_stats)

# %%
#web_scrape_df = ["Player","Team","Age"]

# %%
read_table = pd.read_html(url)
read_table
# Out:
# [      Rk         Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
#  0      1   Álex Abrines  SG  24  OKC  75   8  1134  3.7   9.2  ...  .848  0.8
#  1      2     Quincy Acy  PF  27  BRK  70   8  1359  3.4   9.7  ...  .817  1.1
#  2      3   Steven Adams   C  24  OKC  76  76  2487  6.5  10.3  ...  .559  5.6
#  3      4    Bam Adebayo   C  20  MIA  69  19  1368  4.6   8.9  ...  .721  3.1
#  4      5  Arron Afflalo  SG  32  ORL  53   3   682  3.4   8.6  ...  .846  0.2
#  ..   ...            ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...  ...
#  685  537   Tyler Zeller   C  28  BRK  42  33   703  6.4  11.7  ...  .667  3.2
#  686  537   Tyler Zeller   C  28  MIL  24   1   406  5.5   9.3  ...  .895  4.2
#  687  538    Paul Zipser  SF  23  CHI  54  12   824  3.5  10.2  ...  .760  0.6
#  688  539     Ante Žižić   C  21  CLE  32   2   214  8.2  11.3  ...  .724  4.0
#  689  540    Ivica Zubac   C  20  LAL  43   0   410  5.4  10.7  ...  .765  4.0
#
# ...

# %%
type(read_table)
# Out:
# list

# %%
df = read_table[0]
df.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0  1   Álex Abrines  SG  24  OKC  75   8  1134  3.7   9.2  ...  .848  0.8
# 1  2     Quincy Acy  PF  27  BRK  70   8  1359  3.4   9.7  ...  .817  1.1
# 2  3   Steven Adams   C  24  OKC  76  76  2487  6.5  10.3  ...  .559  5.6
# 3  4    Bam Adebayo   C  20  MIA  69  19  1368  4.6   8.9  ...  .721  3.1
# 4  5  Arron Afflalo  SG  32  ORL  53   3   682  3.4   8.6  ...  .846  0.2
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.8   3.6  0.9  1.2  0.3  0.8  3.9  11.2
# 1  5.7   6.8  1.5  0.9  0.8  1.6  3.9  10.9
# 2  4.4   9.9  1.3  1.3  1.1  1.9  3.1  15.3
# 3  6.9  10.0  2.7  0.8  1.1  1.7  3.6  12.6
# 4  3.3   3.5  1.6  0.2  0.5  1.1  3.0   9.4
#
# [5 rows x 29 columns]

# %%
df = df.reset_index(drop=True)
df.head(50)
# Out:
#     Rk                 Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0    1           Álex Abrines   SG   24  OKC  75   8  1134  3.7   9.2  ...
# 1    2             Quincy Acy   PF   27  BRK  70   8  1359  3.4   9.7  ...
# 2    3           Steven Adams    C   24  OKC  76  76  2487  6.5  10.3  ...
# 3    4            Bam Adebayo    C   20  MIA  69  19  1368  4.6   8.9  ...
# 4    5          Arron Afflalo   SG   32  ORL  53   3   682  3.4   8.6  ...
# 5    6           Cole Aldrich    C   29  MIN  21   0    49  3.7  11.0  ...
# 6    7      LaMarcus Aldridge    C   32  SAS  75  75  2509  9.9  19.3  ...
# 7    8          Jarrett Allen    C   19  BRK  72  31  1441  5.8   9.9  ...
# 8    9           Kadeem Allen   PG   25  BOS  18   1   107  2.0   7.4  ...
# 9   10             Tony Allen   SF   36  NOP  22   0   273  5.8  12.0  ...
# 10  11        Al-Farouq Aminu   PF   27  POR  69  67  2072  4.0  10.1  ...
# ...

# %%
df = df.drop_duplicates(subset=['Player'], keep='first')

# %%
df.to_csv("check.csv")

# %%
df.dtypes

# %%
# convert to csv and then check which rows are not integers and then drop the row.

# %%
df["Age"] = df["Age"].str.replace(',','.').astype('int')

# %%
age_avg = df.groupby(["Tm"]).mean()["Age"].rename("Average Player Age")
age_df = pd.DataFrame(age_avg)
age_df.head()

# %%
tables = pd.read_html()
